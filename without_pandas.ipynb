# %%
from IPython.display import YouTubeVideo
YouTubeVideo('lyDLAutA88s', width=800, height=300)

# %%
# 1. Посмотрите видео Дэвида Бизли про всроенные инструменты Python
# 2. Попробуйте используя встроенные инструменты Python проанализировать таблицу из файла "Vacancy.csv"
# 3. Попробуйте ответить на вопросы:
# Сколько вакансий, которые вам нравятся?
# Насколько свежие эти вакансии?
# Сколько вакансий с позициями на которых вы работаете?
# Сколько вакансий для аналатика данных?
# Сколько вакансий для аналитика данных с использованием Python?

# В задании важно не использовать pandas и numpy, а встроенные инструменты python
# Counter, CSV, defaultdict, sorted

# %%
import csv

# %%
import sys

# %%
csv.field_size_limit(2000000000)
# Out:
# 2000000000

# %%
test = list(csv.DictReader(open(file='D:/vacancy.csv', encoding='utf-8')))

# %%
test[0]
# Out:
# {'id': '383479',
#  'created_at': '2021-03-14 09:39:21.854462',
#  'updated_at': '2021-03-14 09:39:21.854584',
#  'vacid': '1474941',
#  'vactitle': 'Senior java-разработчик (в команду Онбординга)',
#  'vacdescription': ' Работа у нас — это:команда профессионалов, готовых поддержать ваши инициативы;мощное железо, дополнительные мониторы и всё, что нужно для продуктивной работы;обучение за счёт компании;гибкий графиккрасивый и комфортный офис  г. Санкт-Петербург, м. Ладожская  пл. Карла Фаберже 8 ВДМС;прозрачная система бонусов и премий, достойная зарплата — размер обсудим на собеседовании.Информация о проекте:Наша команда делает новые экспериментальные фичи для СБОЛа.Сейчас мы разрабатываем систему, с помощью которой разные команды Сбера смогут создавать квесты для мобильного приложения.Также мы будем разрабатывать внутреннюю платформу для продуктовых экспериментов. Описание команды:2-pizza team: сейчас у нас работают разработчики iOS и Android, продакт и аналитик. К команде в ближайшее время подключится тестировщик и еще один аналитик. Мы ожидаем, что Вы:Работали раннее в продуктовой agile-команде;Имеете опыт работы больше 4 лет с Java и ее экосистемой;Владеете Spring: Core, MVC, Boot, Cloud;Работали с реляционными БД;Трепетно относитесь к тестовому покрытию;Будете относиться с заботой к нашим пользователям, продукту и команде. Будет здорово, если вы:Умеете готовить ansible;Работали с k8s;Использовали kafka;Умеете оптимизировать SQL-запросы. Вам предстоит:отвечать за качество технических решений;придумывать реализацию для безумных идей наших продактов;разрабатывать сервисы, интегрироваться с множеством систем банка.Информация о проекте:Наша команда делает новые экспериментальные фичи для СБОЛа.Сейчас мы разрабатываем систему, с помощью которой разные команды Сбера смогут создавать квесты для мобильного приложения.Также мы будем разрабатывать внутреннюю платформу для продуктовых экспериментов. Описание команды:2-pizza team: сейчас у нас работают разработчики iOS и Android, продакт и аналитик. К команде в ближайшее время подключится тестировщик и еще один аналитик. Мы ожидаем, что Вы:Работали раннее в продуктовой agile-команде;Имеете опыт работы больше 4 лет с Java и ее экосистемой;Владеете Spring: Core, MVC, Boot, Cloud;Работали с реляционными БД;Трепетно относитесь к тестовому покрытию;Будете относиться с заботой к нашим пользователям, продукту и команде. Будет здорово, если вы:Умеете готовить ansible;Работали с k8s;Использовали kafka;Умеете оптимизировать SQL-запросы. Вам предстоит:отвечать за качество технических решений;придумывать реализацию для безумных идей наших продактов;разрабатывать сервисы, интегрироваться с множеством систем банка. Работа у нас — это:команда профессионалов, готовых поддержать ваши инициативы;мощное железо, дополнительные мониторы и всё, что нужно для продуктивной работы;обучение за счёт компании;гибкий графиккрасивый и комфортный офис  г. Санкт-Петербург, м. Ладожская  пл. Карла Фаберже 8 ВДМС;прозрачная система бонусов и премий, достойная зарплата — размер обсудим на собеседовании.',
span lang=\\"ru\\" style=\\"font-size:10.5pt\\"><span style=\\"background:white\\">\\u043c. \\u041b\\u0430\\u0434\\u043e\\u0436\\u0441\\u043a\\u0430\\u044f&nbsp;&nbsp;</span></span><span style=\\"font-size:10.5pt\\">\\u043f\\u043b. \\u041a\\u0430\\u0440\\u043b\\u0430 \\u0424\\u0430\\u0431\\u0435\\u0440\\u0436\\u0435 8 \\u0412</span></li><li class=\\"1\\"><span lang=\\"ru\\" style=\\"font-size:10.5pt\\"><span style=\\"background:white\\">\\u0414\\u041c\\u0421;</span></span></li><li class=\\"1\\"><span lang=\\"ru\\" style=\\"font-size:10.5pt\\"><span style=\\"background:white\\">\\u043f\\u0440\\u043e\\u0437\\u0440\\u0430\\u0447\\u043d\\u0430\\u044f \\u0441\\u0438\\u0441\\u0442\\u0435\\u043c\\u0430 \\u0431\\u043e\\u043d\\u0443\\u0441\\u043e\\u0432 \\u0438 \\u043f\\u0440\\u0435\\u043c\\u0438\\u0439, \\u0434\\u043e\\u0441\\u0442\\u043e\\u0439\\u043d\\u0430\\u044f \\u0437\\u0430\\u0440\\u043f\\u043b\\u0430\\u0442\\u0430 &mdash; \\u0440\\u0430\\u0437\\u043c\\u0435\\u0440 \\u043e\\u0431\\u0441\\u0443\\u0434\\u0438\\u043c \\u043d\\u0430 \\u0441\\u043e\\u0431\\u0435\\u0441\\u0435\\u0434\\u043e\\u0432\\u0430\\u043d\\u0438\\u0438.</span></span></li></ul>", "header": "<p class=\\"1\\"><span style=\\"font-size:14px\\"><strong><span style=\\"background:white\\">\\u0418\\u043d\\u0444\\u043e\\u0440\\u043c\\u0430\\u0446\\u0438\\u044f </span><span lang=\\"ru\\" style=\\"background:white\\">\\u043e \\u043f\\u0440\\u043e\\u0435\\u043 ...

# %%
# Сколько вакансий, которые вам нравятся?
vactitles = []
for vac in test:
    vactitles.append(vac['vactitle'])

# %%
print(vactitles)
# Out:
# ['Senior java-разработчик (в команду Онбординга)', 'Дизайнер мобильных приложений', 'Старший специалист отдела мониторинга залогового обеспечения', "Аналитик/разработчик  (Программа 'Миграция Legacy АС на Фабрику Данных')", 'Java разработчик (Команда Functions)', 'Главный инженер (NGFW)', 'Ведущий инженер по кибербезопасности (защита контейнеров)', 'Тестировщик-автоматизатор (QA)', 'Ведущий специалист (отдел технических средств охраны)', 'Инженер поддержки тестирования', 'Data - аналитик', 'Ведущий специалист (Управление комплаенс)', 'Клиентский менеджер по работе с корпоративными клиентами', 'Главный инженер (Pentest)', 'DevOps (центр снабжения)', 'QA', 'Data engineer (BigData и ML)', 'Лидер АС', 'Системный аналитик. Сервис Автокредитование', 'Руководитель направления ABAP', 'ABAP разработчик под АСУС EWM', 'Аналитик (информационная безопасность)', 'Разработчик ABAP', 'Инженер по разработке', 'Frontend разработчик (React)КБ', 'Product owner AI решений', 'Руководитель проектов', 'Backend-разработчик (web)', 'Front-end разработчик (React, JS)', 'Системный аналитик', 'Java Lead / Java Developer', 'Старший менеджер по обслуживанию (пгт Новоаганск)', 'Стажер', 'Менеджер по продажам (п. Солнечный)', 'Java-разработчик (HR-платформа)', 'Кредитный инспектор отдела мониторинга кредитных операций торговли', 'Стажер школы SQL, PL\\SQL', 'Инженер по нагрузочному тестированию', 'Старший аудитор по проверкам кредитных операций физических лиц', 'JavaScript разработчик(Backend)', 'Инженер Удостоверяющего центра', 'Главный специалист по телемаркетингу', 'Менеджер по нефинансовым сервисам (продажи продуктов экосистемы Сбера корпоративным клиентам)', 'Старший специалист по взысканию', 'Главный дизайнер мобильных приложений', 'Старший дизайнер мобильных приложений', 'Дизайнер мобильных приложений', 'Java разработчик', 'Java. groovy разработчик', 'Главный специалист по взысканию', 'Главный инженер по разработке', 'Мобильный менеджер по продажам', 'Старший специалист по взысканию', 'Старший специалист по взысканию', 'Ведущий специалист по взысканию', 'Старший специалист по взысканию', 'Менеджер по продажам продуктов канала', 'Старший менеджер по обслуживанию (г. Туринск, 7003/0778)', 'Стажер Sberseasons iOS весна \ue013', 'Старший инженер', 'Руководитель направления/Аналитик AI решений', 'Бизнес/системный аналитик', 'Старший менеджер по обслуживанию', 'Lead Frontend Developer', 'Системный аналитик', 'Менеджер по продажам (ЗАТО Озерный)', 'Старший кассир', 'Мобильный менеджер по продажам', 'Мобильный менеджер по продажам', 'Мобильный менеджер по продажам', 'Мобильный менеджер по продажам', 'Специалист по прямым продажам', 'Мобильный менеджер по продажам', 'Мобильный менеджер по продажам', 'Главный клиентский менеджер малого бизнеса', 'Front-end разработчик (RIA/SPA приложения)', 'Ведущий инженер по автоматизированному тестированию', 'Менеджер по продажам (с. Кизильское)', 'Разработчик SAS', 'Java разработчик', 'Инженер по разработке', 'Старший менеджер по обслуживанию', 'Менеджер по продаже зарплатных проектов', 'Android-разработчик (Сервисы ʺПлати QRʺ)', 'Java Developer', 'Frontend разработчик (React)', 'Frontend developer JavaScript (React/Redux)', 'Java developer', 'Java разработчик', 'Тестировщик ПО (QA Automation Engineer)', 'Ведущий инженер (сопровождение системы визуализации отчетности)', 'Старший менеджер по обслуживанию (с. Рудянское)', 'QA Automation Engineer (Python)', 'Инженер по диспетчеризации ЦОД', 'Водитель-инкассатор', 'Ведущий менеджер по обслуживанию', 'Python разработчик (команда "ИСУ")', 'Специалист по разметке данных', 'Аналитик на разметку данных', 'Консультант по работе с ПФР', 'Системный аналитик', 'Старший менеджер по обслуживанию', 'Технологический руководитель команды', 'Старший специалист по взысканию', 'Эксперт', 'Менеджер в Департамент Стратегии (IT/E-Government)', 'Старший специалист судебного и исполнительного производства', 'Водитель', 'Мобильный менеджер по продажам', 'Старший менеджер по обслуживанию', 'IT Аналити ...

# %%
print('Клиентский менеджер' in vactitles)
# Out:
# True

# %%
favvac = Counter(vactitles)

# %%
favvac['Клиентский менеджер']
# Out:
# 10

# %%
# Насколько свежие эти вакансии?
vackl = []
for v in test:
    if v.get('vactitle') == 'Клиентский менеджер':
        vackl.append(v.get('created_at'))

# %%
print(vackl)
# Out:
# ['2021-03-14 09:39:21.854462', '2021-03-14 09:39:21.854462', '2021-03-14 09:39:21.854462', '2021-03-14 09:39:21.854462', '2021-03-14 09:39:21.854462', '2021-03-14 09:39:21.854462', '2021-03-14 09:39:21.854462', '2021-03-14 09:39:21.854462', '2021-03-14 09:39:21.854462', '2021-03-14 09:39:21.854462']

# %%
#Сколько вакансий с позициями на которых вы работаете?
hrvac = Counter(vactitles)

# %%
hrvac['HR аналитик']
# Out:
# 0

# %%
#Сколько вакансий для аналатика данных?
analytvac = Counter(vactitles)

# %%
hrvac['Аналитик данных']
# Out:
# 5

# %%
#Сколько вакансий для аналитика данных с использованием Python?
pythonvac = Counter(vactitles)

# %%
vackl = []
for v in test:
    if 'Аналитик данных' in v.get('vactitle'):
        vackl.append(v.get('vactitle'))
pythonvac = Counter(vackl)
pythonvac['python']
# Out:
# 0
